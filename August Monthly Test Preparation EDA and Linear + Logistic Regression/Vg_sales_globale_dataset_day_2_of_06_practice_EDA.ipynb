# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("vgsalesGlobale.csv" , index_col="Name")

# %%
df
# Out:
#                                                    Rank Platform    Year  \
# Name
# Wii Sports                                            1      Wii  2006.0
# Super Mario Bros.                                     2      NES  1985.0
# Mario Kart Wii                                        3      Wii  2008.0
# Wii Sports Resort                                     4      Wii  2009.0
# Pokemon Red/Pokemon Blue                              5       GB  1996.0
# ...                                                 ...      ...     ...
# Woody Woodpecker in Crazy Castle 5                16596      GBA  2002.0
# Men in Black II: Alien Escape                     16597       GC  2003.0
# SCORE International Baja 1000: The Official Game  16598      PS2  2008.0
# Know How 2                                        16599       DS  2010.0
# Spirits & Spells                                  16600      GBA  2003.0
#
#                                                          Genre   Publisher  \
# Name
# ...

# %%
df.isnull().sum()
# Out:
# Rank              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
df.dtypes
# Out:
# Rank              int64
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
int(df["Year"].isnull().sum())
# Out:
# 271

# %%
df["Year"].head()
# Out:
# Name
# Wii Sports                  2006.0
# Super Mario Bros.           1985.0
# Mario Kart Wii              2008.0
# Wii Sports Resort           2009.0
# Pokemon Red/Pokemon Blue    1996.0
# Name: Year, dtype: float64

# %%
df.shape
# Out:
# (16598, 10)

# %%
df.sort_values(by="Year" , ascending=False)
# Out:
#                                                    Rank Platform    Year  \
# Name
# Imagine: Makeup Artist                             5959       DS  2020.0
# Brothers Conflict: Precious Baby                  16441      PSV  2017.0
# Phantasy Star Online 2 Episode 4: Deluxe Package  14393      PS4  2017.0
# Phantasy Star Online 2 Episode 4: Deluxe Package  16244      PSV  2017.0
# Sumikko Gurashi: Mura o Tsukurundesu              12685      3DS  2016.0
# ...                                                 ...      ...     ...
# Freaky Flyers                                     16310       GC     NaN
# Inversion                                         16330       PC     NaN
# Hakuouki: Shinsengumi Kitan                       16369      PS3     NaN
# Virtua Quest                                      16430       GC     NaN
# The Smurfs                                        16496      3DS     NaN
#
#                                                          Genre  \
# Name
# ...

# %%
df[df["Genre"] == "Racing"]
# Out:
#                                                      Rank Platform    Year  \
# Name
# Mario Kart Wii                                          3      Wii  2008.0
# Mario Kart DS                                          12       DS  2005.0
# Gran Turismo 3: A-Spec                                 29      PS2  2001.0
# Mario Kart 7                                           43      3DS  2011.0
# Gran Turismo 4                                         48      PS2  2004.0
# ...                                                   ...      ...     ...
# Sébastien Loeb Rally Evo                            16533     XOne  2016.0
# Driving Simulator 2011                              16546       PC  2011.0
# Mini Desktop Racing                                 16576      Wii  2007.0
# Yattaman Wii: BikkuriDokkiri Machine de Mou Rac...  16577      Wii  2008.0
# SCORE International Baja 1000: The Official Game    16598      PS2  2008.0
#
#                                                      Genre  \
# ...

# %%
df.head()
# Out:
#                           Rank Platform    Year         Genre Publisher  \
# Name
# Wii Sports                   1      Wii  2006.0        Sports  Nintendo
# Super Mario Bros.            2      NES  1985.0      Platform  Nintendo
# Mario Kart Wii               3      Wii  2008.0        Racing  Nintendo
# Wii Sports Resort            4      Wii  2009.0        Sports  Nintendo
# Pokemon Red/Pokemon Blue     5       GB  1996.0  Role-Playing  Nintendo
#
#                           NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Name
# Wii Sports                   41.49     29.02      3.77         8.46
# Super Mario Bros.            29.08      3.58      6.81         0.77
# Mario Kart Wii               15.85     12.88      3.79         3.31
# Wii Sports Resort            15.75     11.01      3.28         2.96
# Pokemon Red/Pokemon Blue     11.27      8.89     10.22         1.00
#
#                           Global_Sales
# Name
# Wii Sports                       82.74
# ...

# %%
df.shape
# Out:
# (16598, 10)

# %%
data_after_2015 = df["Year"] > 2015

# %%
df[data_after_2015]
# Out:
#                                                      Rank Platform    Year  \
# Name
# FIFA 17                                               222      PS4  2016.0
# Uncharted 4: A Thief's End                            272      PS4  2016.0
# Tom Clancy's The Division                             352      PS4  2016.0
# Far Cry: Primal                                       772      PS4  2016.0
# Tom Clancy's The Division                             847     XOne  2016.0
# ...                                                   ...      ...     ...
# Mighty No. 9                                        16565     XOne  2016.0
# Resident Evil 4 HD                                  16572     XOne  2016.0
# Farming 2017 - The Simulation                       16573      PS4  2016.0
# Rugby Challenge 3                                   16579     XOne  2016.0
# Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shirub...  16592      PSV  2016.0
#
# ...

# %% [markdown]
# # **Let's find the Median of Global Sales**

# %%
median_of_global_sales = df["Global_Sales"].median()

# %%
median_of_global_sales
# Out:
# 0.17
